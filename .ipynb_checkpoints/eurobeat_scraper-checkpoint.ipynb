# %%
import numpy as np
import pandas as pd
import requests
import bs4
import lxml.etree as xml
from IPython.display import HTML, display

# %%
#progress bar
def progress(value, max=100):
    return HTML("""
        <progress
            value='{value}'
            max='{max}',
            style='width: 90%'
        >
            {value}
        </progress>
    """.format(value=value, max=max))

# %%
#index of first and last song (MAXIMUM: 4433)
song_min = 1
song_max = 100 #4433

song = 0

#open 'eurobeat_lyrics.txt' in my drive and delete its previous context
file = 'eurobeat_lyrics.csv'
file = open(file, mode='w')
file.truncate(0)

#progess bar
out = display(progress(0, 100), display_id=True)
    
#eurobeat-prime indexes its database, which we will loop over
for i in range(song_min, song_max):
    URL = f'https://www.eurobeat-prime.com/lyrics.php?lyrics={i}'
    requests.get(URL, {}).text

    #beautifoul soup object
    web_page = bs4.BeautifulSoup(requests.get(URL, {}).text, "lxml")
    #filter html
    sub_web_page = web_page.find_all(name="div", attrs={"class": "mmids"})[0]

    #extract lyrics
    lyrics = sub_web_page.get_text()
    lyrics = lyrics.split('\n', 2)[2]              
    
    #write lyrics to file in drive
    file.write(lyrics)
    file.write(';') #seperation of data

    
    #process
    out.update(progress(i+1, song_max))
    print(f'{i}/{song_max}')



file.close()
# Out:
#         <progress
#             value='100'
#             max='100',
#             style='width: 90%'
#         >
#             100
#         </progress>
# 1/100
# 2/100
# 3/100
# 4/100
# 5/100
# 6/100
# 7/100
# 8/100
# 9/100
# 10/100
# 11/100
# 12/100
# 13/100
# 14/100
# 15/100
# 16/100
# 17/100
# 18/100
# 19/100
# 20/100
# 21/100
# 22/100
# 23/100
# 24/100
# 25/100
# 26/100
# 27/100
# 28/100
# 29/100
# 30/100
# 31/100
# 32/100
# 33/100
# 34/100
# 35/100
# 36/100
# 37/100
# 38/100
# 39/100
# 40/100
# 41/100
# 42/100
# 43/100
# 44/100
# 45/100
# 46/100
# 47/100
# 48/100
# 49/100
# 50/100
# 51/100
# 52/100
# 53/100
# 54/100
# 55/100
# 56/100
# 57/100
# 58/100
# 59/100
# 60/100
# 61/100
# 62/100
# 63/100
# 64/100
# 65/100
# 66/100
# 67/100
# 68/100
# 69/100
# 70/100
# 71/100
# 72/100
# 73/100
# 74/100
# 75/100
# 76/100
# 77/100
# 78/100
# 79/100
# 80/100
# 81/100
# 82/100
# 83/100
# 84/100
# 85/100
# 86/100
# 87/100
# 88/100
# 89/100
# 90/100
# 91/100
# 92/100
# 93/100
# 94/100
# 95/100
# 96/100
# 97/100
# 98/100
# 99/100
